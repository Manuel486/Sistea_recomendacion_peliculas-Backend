# %%
import pandas as pd
import mysql.connector

# Configura la conexión a MySQL
conexion = mysql.connector.connect(
    host="localhost",
    port="3306",
    user="root",
    password="root",
    database="srp",
)

# %%
# Configura la conexión a MySQL
conexion = mysql.connector.connect(
    host="localhost",
    port="3306",
    user="root",
    password="root",
    database="srp",
)

# user 
# Ruta al archivo CSV que deseas cargar
archivo_csv = "./data/user_data.csv"

try:
    # Lee el archivo CSV en un DataFrame
    df = pd.read_csv(archivo_csv)

    # Convierte los nombres de las columnas a minúsculas
    df.columns = [col.lower() for col in df.columns]

    # Carga los datos en la tabla existente en MySQL
    cursor = conexion.cursor()

    for index, row in df.iterrows():
        # Realiza la inserción en la base de datos
        cursor.execute(
            """
            INSERT INTO user (names,lastnames,email,password)
            VALUES (%s, %s, %s, %s)
        """,
            (
                str(row["names"]),
                str(row["last_names"]),
                str(row["email"]),
                str(row["password"]),
            ),
        )

    # Confirma la transacción
    conexion.commit()

    print("Datos cargados exitosamente en la tabla de MySQL.")

except mysql.connector.Error as err:
    print("Error al cargar datos en la tabla de MySQL:", err)

finally:
    # Cierra el cursor y la conexión a MySQL
    cursor.close()
    conexion.close()
# Out:
# Datos cargados exitosamente en la tabla de MySQL.

# %%
# Configura la conexión a MySQL
conexion = mysql.connector.connect(
    host="localhost",
    port="3306",
    user="root",
    password="root",
    database="srp",
)

# movie
# Ruta al archivo CSV que deseas cargar
archivo_csv = "./data/movies_data.csv"

try:
    # Lee el archivo CSV en un DataFrame
    df = pd.read_csv(archivo_csv)

    # Convierte los nombres de las columnas a minúsculas
    df.columns = [col.lower() for col in df.columns]

    # Carga los datos en la tabla existente en MySQL
    cursor = conexion.cursor()

    for index, row in df.iterrows():
        # Realiza la inserción en la base de datos
        cursor.execute(
            """
            INSERT INTO movie (id,title,year)
            VALUES (%s, %s, %s) 
        """,
            (
                row['movieid'],
                str(row["title"]),
                row["year"],
            ),
        )

    # Confirma la transacción
    conexion.commit()

    print("Datos cargados exitosamente en la tabla de MySQL.")

except mysql.connector.Error as err:
    print("Error al cargar datos en la tabla de MySQL:", err)

finally:
    # Cierra el cursor y la conexión a MySQL
    cursor.close()
    conexion.close()
# Out:
# Error al cargar datos en la tabla de MySQL: 1054 (42S22): Unknown column 'nan' in 'field list'

# %%
# Configura la conexión a MySQL
conexion = mysql.connector.connect(
    host="localhost",
    port="3306",
    user="root",
    password="root",
    database="srp",
)

# rating
# Ruta al archivo CSV que deseas cargar
archivo_csv = "./data/ratings_data.csv"

try:
    # Lee el archivo CSV en un DataFrame
    df = pd.read_csv(archivo_csv)

    # Convierte los nombres de las columnas a minúsculas
    df.columns = [col.lower() for col in df.columns]

    # Carga los datos en la tabla existente en MySQL
    cursor = conexion.cursor()

    for index, row in df.iterrows():
        # Realiza la inserción en la base de datos
        cursor.execute(
            """
            INSERT INTO rating (userId, rating, movieId)
            VALUES (%s, %s, %s)""",
            (int(row["userid"]), float(row["rating"]), int(row["movieid"])),
        )

    # Confirma la transacción
    conexion.commit()

    print("Datos cargados exitosamente en la tabla de MySQL.")

except mysql.connector.Error as err:
    print("Error al cargar datos en la tabla de MySQL:", err)

finally:
    # Cierra el cursor y la conexión a MySQL
    cursor.close()
    conexion.close()
# Out:
# Datos cargados exitosamente en la tabla de MySQL.

# %%
# Configura la conexión a MySQL
conexion = mysql.connector.connect(
    host="localhost",
    port="3306",
    user="root",
    password="root",
    database="srp",
)

# Ruta al archivo CSV que deseas cargar
archivo_csv = "./data/links_data.csv"

try:
    # Lee el archivo CSV en un DataFrame
    df = pd.read_csv(archivo_csv)

    # Convierte los nombres de las columnas a minúsculas
    df.columns = [col.lower() for col in df.columns]

    # Carga los datos en la tabla existente en MySQL
    cursor = conexion.cursor()

    for index, row in df.iterrows():
        imdb_id = int(row["imdbid"])
        tmdb_id = int(row["tmdbid"])
        movie_id = int(row["movieid"])

        # Verifica si el movieId existe en la tabla movie
        cursor.execute("SELECT COUNT(*) FROM movie WHERE id = %s", (movie_id,))
        count = cursor.fetchone()[0]

        if count > 0:
            # El movieId existe, se puede insertar en la tabla link
            cursor.execute(
                """
                INSERT INTO link (movieId, imdbId, tmdbId)
                VALUES (%s, %s, %s)
                """,
                (movie_id, imdb_id, tmdb_id),
            )
        else:
            print(f"El movieId {movie_id} no existe en la tabla movie. Fila ignorada.")


    conexion.commit()

    print("Datos cargados exitosamente en la tabla de MySQL.")

except mysql.connector.Error as err:
    print("Error al cargar datos en la tabla de MySQL:", err)

finally:
    # Cierra el cursor y la conexión a MySQL
    cursor.close()
# Out:
# El movieId 1 no existe en la tabla movie. Fila ignorada.
# El movieId 2 no existe en la tabla movie. Fila ignorada.
# El movieId 3 no existe en la tabla movie. Fila ignorada.
# El movieId 4 no existe en la tabla movie. Fila ignorada.
# El movieId 5 no existe en la tabla movie. Fila ignorada.
# El movieId 6 no existe en la tabla movie. Fila ignorada.
# El movieId 7 no existe en la tabla movie. Fila ignorada.
# El movieId 8 no existe en la tabla movie. Fila ignorada.
# El movieId 9 no existe en la tabla movie. Fila ignorada.
# El movieId 10 no existe en la tabla movie. Fila ignorada.
# El movieId 11 no existe en la tabla movie. Fila ignorada.
# El movieId 12 no existe en la tabla movie. Fila ignorada.
# El movieId 13 no existe en la tabla movie. Fila ignorada.
# El movieId 14 no existe en la tabla movie. Fila ignorada.
# El movieId 15 no existe en la tabla movie. Fila ignorada.
# El movieId 16 no existe en la tabla movie. Fila ignorada.
# El movieId 17 no existe en la tabla movie. Fila ignorada.
# El movieId 18 no existe en la tabla movie. Fila ignorada.
# El movieId 19 no existe en la tabla movie. Fila ignorada.
# El movieId 20 no existe en la tabla movie. Fila ignorada.
# El movieId 21 no existe en la tabla movie. Fila ignorada.
# El movieId 22 no existe en la tabla movie. Fila ignorada.
# El movieId 23 no existe en la tabla movie. Fila ignorada.
# El movieId 24 no existe en la tabla movie. Fila ignorada.
# El movieId 25 no existe en la tabla movie. Fila ignorada.
# El movieId 26 no existe en la tabla movie. Fila ignorada.
# El movieId 27 no existe en la tabla movie. Fila ignorada.
# El movieId 28 no existe en la tabla movie. Fila ignorada.
# El movieId 29 no existe en la tabla movie. Fila ignorada.
# El movieId 30 no existe en la tabla movie. Fila ignorada.
# El movieId 31 no existe en la tabla movie. Fila ignorada.
# El movieId 32 no existe en la tabla movie. Fila ignorada.
# El movieId 34 no existe en la tabla movie. Fila ignorada.
# El movieId 36 no existe en la tabla movie. Fila ignorada.
# El movieId 38 no existe en la tabla movie. Fila ignorada.
# El movieId 39 no existe en la tabla movie. Fila ignorada.
# El movieId 40 no existe en la tabla movie. Fila ignorada.
# El movieId 41 no existe en la tabla movie. Fila ignorada.
# El movieId 42 no existe en la tabla movie. Fila ignorada.
# El movieId 43 no existe en la tabla movie. Fila ignorada.
# El movieId 44 no existe en la tabla movie. Fila ignorada.
# El movieId 45 no existe en la tabla movie. Fila ignorada.
# El movieId 46 no existe en la tabla movie. Fila ignorada.
# El movieId 47 no existe en la tabla movie. Fila ignorada.
# El movieId 48 no existe en la tabla movie. Fila ignorada.
# El movieId 49 no existe en la tabla movie. Fila ignorada.
# El movieId 50 no existe en la tabla movie. Fila ignorada.
# El movieId 52 no existe en la tabla movie. Fila ignorada.
# El movieId 53 no existe en la tabla movie. Fila ignorada.
# El movieId 54 no existe en la tabla movie. Fila ignorada.
# El movieId 55 no existe en la tabla movie. Fila ignorada.
# El movieId 57 no existe en la tabla movie. Fila ignorada.
# El movieId 58 no existe en la tabla movie. Fila ignorada.
# El movieId 60 no existe en la tabla movie. Fila ignorada.
# El movieId 61 no existe en la tabla movie. Fila ignorada.
# El movieId 62 no existe en la tabla movie. Fila ignorada.
# El movieId 63 no existe en la tabla movie. Fila ignorada.
# El movieId 64 no existe en la tabla movie. Fila ignorada.
# El movieId 65 no existe en la tabla movie. Fila ignorada.
# El movieId 66 no existe en la tabla movie. Fila ignorada.
# El movieId 68 no existe en la tabla movie. Fila ignorada.
# El movieId 69 no existe en la tabla movie. Fila ignorada.
# El movieId 70 no existe en la tabla movie. Fila ignorada.
# El movieId 71 no existe en la tabla movie. Fila ignorada.
# El movieId 72 no existe en la tabla movie. Fila ignorada.
# El movieId 73 no existe en la tabla movie. Fila ignorada.
# El movieId 74 no existe en la tabla movie. Fila ignorada.
# El movieId 75 no existe en la tabla movie. Fila ignorada.
# El movieId 76 no existe en la tabla movie. Fila ignorada.
# El movieId 77 no existe en la tabla movie. Fila ignorada.
# El movieId 78 no existe en la tabla movie. Fila ignorada.
# El movieId 79 no existe en la tabla movie. Fila ignorada.
# El movieId 80 no existe en la tabla movie. Fila ignorada.
# El movieId 81 no existe en la tabla movie. Fila ignorada.
# El movieId 82 no existe en la tabla movie. Fila ignorada.
# El movieId 83 no existe en la tabla movie. Fila ignorada.
# El movieId 85 no existe en la tabla movie. Fila ignorada.
# El movieId 86 no existe en la tabla movie. Fila ignorada.
# El movieId 87 no existe en la tabla movie. Fila ignorada.
# El movieId 88 no existe en la tabla movie. Fila ignorada.
# El movieId 89 no existe en la tabla movie. Fila ignorada.
# El movieId 92 no existe en la tabla movie. Fila ignorada.
# El movieId 93 no existe en la tabla movie. Fila ignorada.
# El movieId 94 no existe en la tabla movie. Fila ignorada.
# El movieId 95 no existe en la tabla movie. Fila ignorada.
# El movieId 96 no existe en la tabla movie. Fila ignorada.
# El movieId 97 no existe en la tabla movie. Fila ignorada.
# El movieId 99 no existe en la tabla movie. Fila ignorada.
# El movieId 100 no existe en la tabla movie. Fila ignorada.
# El movieId 101 no existe en la tabla movie. Fila ignorada.
# El movieId 102 no existe en la tabla movie. Fila ignorada.
# El movieId 103 no existe en la tabla movie. Fila ignorada.
# El movieId 104 no existe en la tabla movie. Fila ignorada.
# El movieId 105 no existe en la tabla movie. Fila ignorada.
# El movieId 106 no existe en la tabla movie. Fila ignorada.
# El movieId 107 no existe en la tabla movie. Fila ignorada.
# El movieId 108 no existe en la tabla movie. Fila ignorada.
# El movieId 110 no existe en la tabla movie. Fila ignorada.
# El movieId 111 no existe en la tabla movie. Fila ignorada.
# El movieId 112 no existe en la tabla movie. Fila ignorada.
# El movieId 113 no existe en la tabla movie. Fila ignorada.
# El movieId 116 no existe en la tabla movie. Fila ignorada.
# El movieId 117 no existe en la tabla movie. Fila ignorada.
# El movieId 118 no existe en la tabla movie. Fila ignorada.
# El movieId 119 no existe en la tabla movie. Fila ignorada.
# El movieId 121 no existe en la tabla movie. Fila ignorada.
# El movieId 122 no existe en la tabla movie. Fila ignorada.
# El movieId 123 no existe en la tabla movie. Fila ignorada.
# El movieId 125 no existe en la tabla movie. Fila ignorada.
# El movieId 126 no existe en la tabla movie. Fila ignorada.
# El movieId 128 no existe en la tabla movie. Fila ignorada.
# El movieId 129 no existe en la tabla movie. Fila ignorada.
# El movieId 132 no existe en la tabla movie. Fila ignorada.
# El movieId 135 no existe en la tabla movie. Fila ignorada.
# El movieId 137 no existe en la tabla movie. Fila ignorada.
# El movieId 140 no existe en la tabla movie. Fila ignorada.
# El movieId 141 no existe en la tabla movie. Fila ignorada.
# El movieId 144 no existe en la tabla movie. Fila ignorada.
# El movieId 145 no existe en la tabla movie. Fila ignorada.
# El movieId 146 no existe en la tabla movie. Fila ignorada.
# El movieId 147 no existe en la tabla movie. Fila ignorada.
# El movieId 148 no existe en la tabla movie. Fila ignorada.
# El movieId 149 no existe en la tabla movie. Fila ignorada.
# El movieId 150 no existe en la tabla movie. Fila ignorada.
# El movieId 151 no existe en la tabla movie. Fila ignorada.
# El movieId 152 no existe en la tabla movie. Fila ignorada.
# El movieId 153 no existe en la tabla movie. Fila ignorada.
# El movieId 154 no existe en la tabla movie. Fila ignorada.
# El movieId 155 no existe en la tabla movie. Fila ignorada.
# El movieId 156 no existe en la tabla movie. Fila ignorada.
# El movieId 157 no existe en la tabla movie. Fila ignorada.
# El movieId 158 no existe en la tabla movie. Fila ignorada.
# El movieId 159 no existe en la tabla movie. Fila ignorada.
# El movieId 160 no existe en la tabla movie. Fila ignorada.
# El movieId 161 no existe en la tabla movie. Fila ignorada.
# El movieId 162 no existe en la tabla movie. Fila ignorada.
# El movieId 163 no existe en la tabla movie. Fila ignorada.
# El movieId 164 no existe en la tabla movie. Fila ignorada.
# El movieId 165 no existe en la tabla movie. Fila ignorada.
# El movieId 166 no existe en la tabla movie. Fila ignorada.
# El movieId 168 no existe en la tabla movie. Fila ignorada.
# El movieId 169 no existe en la tabla movie. Fila ignorada.
# El movieId 170 no existe en la tabla movie. Fila ignorada.
# El movieId 171 no existe en la tabla movie. Fila ignorada.
# El movieId 172 no existe en la tabla movie. Fila ignorada.
# El movieId 173 no existe en la tabla movie. Fila ignorada.
# El movieId 174 no existe en la tabla movie. Fila ignorada.
# El movieId 175 no existe en la tabla movie. Fila ignorada.
# El movieId 176 no existe en la tabla movie. Fila ignorada.
# El movieId 177 no existe en la tabla movie. Fila ignorada.
# El movieId 178 no existe en la tabla movie. Fila ignorada.
# El movieId 179 no existe en la tabla movie. Fila ignorada.
# El movieId 180 no existe en la tabla movie. Fila ignorada.
# El movieId 181 no existe en la tabla movie. Fila ignorada.
# El movieId 183 no existe en la tabla movie. Fila ignorada.
# El movieId 184 no existe en la tabla movie. Fila ignorada.
# El movieId 185 no existe en la tabla movie. Fila ignorada.
# El movieId 186 no existe en la tabla movie. Fila ignorada.
# El movieId 187 no existe en la tabla movie. Fila ignorada.
# El movieId 188 no existe en la tabla movie. Fila ignorada.
# El movieId 189 no existe en la tabla movie. Fila ignorada.
# El movieId 190 no existe en la tabla movie. Fila ignorada.
# El movieId 191 no existe en la tabla movie. Fila ignorada.
# El movieId 193 no existe en la tabla movie. Fila ignorada.
# El movieId 194 no existe en la tabla movie. Fila ignorada.
# El movieId 195 no existe en la tabla movie. Fila ignorada.
# El movieId 196 no existe en la tabla movie. Fila ignorada.
# El movieId 198 no existe en la tabla movie. Fila ignorada.
# El movieId 199 no existe en la tabla movie. Fila ignorada.
# El movieId 201 no existe en la tabla movie. Fila ignorada.
# El movieId 202 no existe en la tabla movie. Fila ignorada.
# El movieId 203 no existe en la tabla movie. Fila ignorada.
# El movieId 204 no existe en la tabla movie. Fila ignorada.
# El movieId 205 no existe en la tabla movie. Fila ignorada.
# El movieId 206 no existe en la tabla movie. Fila ignorada.
# El movieId 207 no existe en la tabla movie. Fila ignorada.
# El movieId 208 no existe en la tabla movie. Fila ignorada.
# El movieId 209 no existe en la tabla movie. Fila ignorada.
# El movieId 210 no existe en la tabla movie. Fila ignorada.
# El movieId 211 no existe en la tabla movie. Fila ignorada.
# El movieId 212 no existe en la tabla movie. Fila ignorada.
# El movieId 213 no existe en la tabla movie. Fila ignorada.
# El movieId 214 no existe en la tabla movie. Fila ignorada.
# El movieId 215 no existe en la tabla movie. Fila ignorada.
# El movieId 216 no existe en la tabla movie. Fila ignorada.
# El movieId 217 no existe en la tabla movie. Fila ignorada.
# El movieId 218 no existe en la tabla movie. Fila ignorada.
# El movieId 219 no existe en la tabla movie. Fila ignorada.
# El movieId 220 no existe en la tabla movie. Fila ignorada.
# El movieId 222 no existe en la tabla movie. Fila ignorada.
# El movieId 223 no existe en la tabla movie. Fila ignorada.
# El movieId 224 no existe en la tabla movie. Fila ignorada.
# El movieId 225 no existe en la tabla movie. Fila ignorada.
# El movieId 227 no existe en la tabla movie. Fila ignorada.
# El movieId 228 no existe en la tabla movie. Fila ignorada.
# El movieId 229 no existe en la tabla movie. Fila ignorada.
# El movieId 230 no existe en la tabla movie. Fila ignorada.
# El movieId 231 no existe en la tabla movie. Fila ignorada.
# El movieId 232 no existe en la tabla movie. Fila ignorada.
# El movieId 233 no existe en la tabla movie. Fila ignorada.
# El movieId 234 no existe en la tabla movie. Fila ignorada.
# El movieId 235 no existe en la tabla movie. Fila ignorada.
# El movieId 236 no existe en la tabla movie. Fila ignorada.
# El movieId 237 no existe en la tabla movie. Fila ignorada.
# El movieId 238 no existe en la tabla movie. Fila ignorada.
# El movieId 239 no existe en la tabla movie. Fila ignorada.
# El movieId 240 no existe en la tabla movie. Fila ignorada.
# El movieId 241 no existe en la tabla movie. Fila ignorada.
# El movieId 242 no existe en la tabla movie. Fila ignorada.
# El movieId 243 no existe en la tabla movie. Fila ignorada.
# El movieId 246 no existe en la tabla movie. Fila ignorada.
# El movieId 247 no existe en la tabla movie. Fila ignorada.
# El movieId 248 no existe en la tabla movie. Fila ignorada.
# El movieId 249 no existe en la tabla movie. Fila ignorada.
# El movieId 250 no existe en la tabla movie. Fila ignorada.
# El movieId 251 no existe en la tabla movie. Fila ignorada.
# El movieId 252 no existe en la tabla movie. Fila ignorada.
# El movieId 253 no existe en la tabla movie. Fila ignorada.
# El movieId 254 no existe en la tabla movie. Fila ignorada.
# El movieId 255 no existe en la tabla movie. Fila ignorada.
# El movieId 256 no existe en la tabla movie. Fila ignorada.
# El movieId 257 no existe en la tabla movie. Fila ignorada.
# El movieId 258 no existe en la tabla movie. Fila ignorada.
# El movieId 259 no existe en la tabla movie. Fila ignorada.
# El movieId 260 no existe en la tabla movie. Fila ignorada.
# El movieId 261 no existe en la tabla movie. Fila ignorada.
# El movieId 262 no existe en la tabla movie. Fila ignorada.
# El movieId 263 no existe en la tabla movie. Fila ignorada.
# El movieId 265 no existe en la tabla movie. Fila ignorada.
# El movieId 266 no existe en la tabla movie. Fila ignorada.
# El movieId 267 no existe en la tabla movie. Fila ignorada.
# El movieId 269 no existe en la tabla movie. Fila ignorada.
# El movieId 270 no existe en la tabla movie. Fila ignorada.
# El movieId 271 no existe en la tabla movie. Fila ignorada.
# El movieId 272 no existe en la tabla movie. Fila ignorada.
# El movieId 273 no existe en la tabla movie. Fila ignorada.
# El movieId 274 no existe en la tabla movie. Fila ignorada.
# El movieId 275 no existe en la tabla movie. Fila ignorada.
# El movieId 276 no existe en la tabla movie. Fila ignorada.
# El movieId 277 no existe en la tabla movie. Fila ignorada.
# El movieId 278 no existe en la tabla movie. Fila ignorada.
# El movieId 279 no existe en la tabla movie. Fila ignorada.
# El movieId 280 no existe en la tabla movie. Fila ignorada.
# El movieId 281 no existe en la tabla movie. Fila ignorada.
# El movieId 282 no existe en la tabla movie. Fila ignorada.
# El movieId 283 no existe en la tabla movie. Fila ignorada.
# El movieId 284 no existe en la tabla movie. Fila ignorada.
# El movieId 285 no existe en la tabla movie. Fila ignorada.
# El movieId 287 no existe en la tabla movie. Fila ignorada.
# El movieId 288 no existe en la tabla movie. Fila ignorada.
# El movieId 289 no existe en la tabla movie. Fila ignorada.
# El movieId 290 no existe en la tabla movie. Fila ignorada.
# El movieId 291 no existe en la tabla movie. Fila ignorada.
# El movieId 292 no existe en la tabla movie. Fila ignorada.
# El movieId 293 no existe en la tabla movie. Fila ignorada.
# El movieId 294 no existe en la tabla movie. Fila ignorada.
# El movieId 295 no existe en la tabla movie. Fila ignorada.
# El movieId 296 no existe en la tabla movie. Fila ignorada.
# El movieId 298 no existe en la tabla movie. Fila ignorada.
# El movieId 299 no existe en la tabla movie. Fila ignorada.
# El movieId 300 no existe en la tabla movie. Fila ignorada.
# El movieId 301 no existe en la tabla movie. Fila ignorada.
# El movieId 302 no existe en la tabla movie. Fila ignorada.
# El movieId 303 no existe en la tabla movie. Fila ignorada.
# El movieId 304 no existe en la tabla movie. Fila ignorada.
# El movieId 305 no existe en la tabla movie. Fila ignorada.
# El movieId 306 no existe en la tabla movie. Fila ignorada.
# El movieId 307 no existe en la tabla movie. Fila ignorada.
# El movieId 308 no existe en la tabla movie. Fila ignorada.
# El movieId 310 no existe en la tabla movie. Fila ignorada.
# El movieId 311 no existe en la tabla movie. Fila ignorada.
# El movieId 312 no existe en la tabla movie. Fila ignorada.
# El movieId 313 no existe en la tabla movie. Fila ignorada.
# El movieId 314 no existe en la tabla movie. Fila ignorada.
# El movieId 315 no existe en la tabla movie. Fila ignorada.
# El movieId 316 no existe en la tabla movie. Fila ignorada.
# El movieId 317 no existe en la tabla movie. Fila ignorada.
# El movieId 318 no existe en la tabla movie. Fila ignorada.
# El movieId 319 no existe en la tabla movie. Fila ignorada.
# El movieId 320 no existe en la tabla movie. Fila ignorada.
# El movieId 321 no existe en la tabla movie. Fila ignorada.
# El movieId 322 no existe en la tabla movie. Fila ignorada.
# El movieId 324 no existe en la tabla movie. Fila ignorada.
# El movieId 325 no existe en la tabla movie. Fila ignorada.
# El movieId 326 no existe en la tabla movie. Fila ignorada.
# El movieId 327 no existe en la tabla movie. Fila ignorada.
# El movieId 328 no existe en la tabla movie. Fila ignorada.
# El movieId 329 no existe en la tabla movie. Fila ignorada.
# El movieId 330 no existe en la tabla movie. Fila ignorada.
# El movieId 331 no existe en la tabla movie. Fila ignorada.
# El movieId 332 no existe en la tabla movie. Fila ignorada.
# El movieId 333 no existe en la tabla movie. Fila ignorada.
# El movieId 334 no existe en la tabla movie. Fila ignorada.
# El movieId 335 no existe en la tabla movie. Fila ignorada.
# El movieId 336 no existe en la tabla movie. Fila ignorada.
# El movieId 337 no existe en la tabla movie. Fila ignorada.
# El movieId 338 no existe en la tabla movie. Fila ignorada.
# El movieId 339 no existe en la tabla movie. Fila ignorada.
# El movieId 340 no existe en la tabla movie. Fila ignorada.
# El movieId 341 no existe en la tabla movie. Fila ignorada.
# El movieId 342 no existe en la tabla movie. Fila ignorada.
# El movieId 343 no existe en la tabla movie. Fila ignorada.
# El movieId 344 no existe en la tabla movie. Fila ignorada.
# El movieId 345 no existe en la tabla movie. Fila ignorada.
# El movieId 346 no existe en la tabla movie. Fila ignorada.
# El movieId 347 no existe en la tabla movie. Fila ignorada.
# El movieId 348 no existe en la tabla movie. Fila ignorada.
# El movieId 349 no existe en la tabla movie. Fila ignorada.
# El movieId 350 no existe en la tabla movie. Fila ignorada.
# El movieId 351 no existe en la tabla movie. Fila ignorada.
# El movieId 352 no existe en la tabla movie. Fila ignorada.
# El movieId 353 no existe en la tabla movie. Fila ignorada.
# El movieId 354 no existe en la tabla movie. Fila ignorada.
# El movieId 355 no existe en la tabla movie. Fila ignorada.
# El movieId 356 no existe en la tabla movie. Fila ignorada.
# El movieId 357 no existe en la tabla movie. Fila ignorada.
# El movieId 358 no existe en la tabla movie. Fila ignorada.
# El movieId 359 no existe en la tabla movie. Fila ignorada.
# El movieId 360 no existe en la tabla movie. Fila ignorada.
# El movieId 361 no existe en la tabla movie. Fila ignorada.
# El movieId 362 no existe en la tabla movie. Fila ignorada.
# El movieId 363 no existe en la tabla movie. Fila ignorada.
# El movieId 364 no existe en la tabla movie. Fila ignorada.
# El movieId 365 no existe en la tabla movie. Fila ignorada.
# El movieId 366 no existe en la tabla movie. Fila ignorada.
# El movieId 367 no existe en la tabla movie. Fila ignorada.
# El movieId 368 no existe en la tabla movie. Fila ignorada.
# El movieId 369 no existe en la tabla movie. Fila ignorada.
# El movieId 370 no existe en la tabla movie. Fila ignorada.
# El movieId 371 no existe en la tabla movie. Fila ignorada.
# El movieId 372 no existe en la tabla movie. Fila ignorada.
# El movieId 373 no existe en la tabla movie. Fila ignorada.
# El movieId 374 no existe en la tabla movie. Fila ignorada.
# El movieId 376 no existe en la tabla movie. Fila ignorada.
# El movieId 377 no existe en la tabla movie. Fila ignorada.
# El movieId 378 no existe en la tabla movie. Fila ignorada.
# El movieId 379 no existe en la tabla movie. Fila ignorada.
# El movieId 380 no existe en la tabla movie. Fila ignorada.
# El movieId 381 no existe en la tabla movie. Fila ignorada.
# El movieId 382 no existe en la tabla movie. Fila ignorada.
# El movieId 383 no existe en la tabla movie. Fila ignorada.
# El movieId 384 no existe en la tabla movie. Fila ignorada.
# El movieId 385 no existe en la tabla movie. Fila ignorada.
# El movieId 386 no existe en la tabla movie. Fila ignorada.
# El movieId 387 no existe en la tabla movie. Fila ignorada.
# El movieId 388 no existe en la tabla movie. Fila ignorada.
# El movieId 389 no existe en la tabla movie. Fila ignorada.
# El movieId 390 no existe en la tabla movie. Fila ignorada.
# El movieId 391 no existe en la tabla movie. Fila ignorada.
# El movieId 393 no existe en la tabla movie. Fila ignorada.
# El movieId 405 no existe en la tabla movie. Fila ignorada.
# El movieId 406 no existe en la tabla movie. Fila ignorada.
# El movieId 407 no existe en la tabla movie. Fila ignorada.
# El movieId 408 no existe en la tabla movie. Fila ignorada.
# El movieId 409 no existe en la tabla movie. Fila ignorada.
# El movieId 410 no existe en la tabla movie. Fila ignorada.
# El movieId 412 no existe en la tabla movie. Fila ignorada.
# El movieId 413 no existe en la tabla movie. Fila ignorada.
# El movieId 414 no existe en la tabla movie. Fila ignorada.
# El movieId 415 no existe en la tabla movie. Fila ignorada.
# El movieId 416 no existe en la tabla movie. Fila ignorada.
# El movieId 417 no existe en la tabla movie. Fila ignorada.
# El movieId 418 no existe en la tabla movie. Fila ignorada.
# El movieId 419 no existe en la tabla movie. Fila ignorada.
# El movieId 420 no existe en la tabla movie. Fila ignorada.
# El movieId 421 no existe en la tabla movie. Fila ignorada.
# El movieId 422 no existe en la tabla movie. Fila ignorada.
# El movieId 423 no existe en la tabla movie. Fila ignorada.
# El movieId 424 no existe en la tabla movie. Fila ignorada.
# El movieId 425 no existe en la tabla movie. Fila ignorada.
# El movieId 426 no existe en la tabla movie. Fila ignorada.
# El movieId 427 no existe en la tabla movie. Fila ignorada.
# El movieId 428 no existe en la tabla movie. Fila ignorada.
# El movieId 429 no existe en la tabla movie. Fila ignorada.
# El movieId 430 no existe en la tabla movie. Fila ignorada.
# El movieId 431 no existe en la tabla movie. Fila ignorada.
# El movieId 432 no existe en la tabla movie. Fila ignorada.
# El movieId 433 no existe en la tabla movie. Fila ignorada.
# El movieId 434 no existe en la tabla movie. Fila ignorada.
# El movieId 435 no existe en la tabla movie. Fila ignorada.
# El movieId 436 no existe en la tabla movie. Fila ignorada.
# El movieId 437 no existe en la tabla movie. Fila ignorada.
# El movieId 438 no existe en la tabla movie. Fila ignorada.
# El movieId 440 no existe en la tabla movie. Fila ignorada.
# El movieId 441 no existe en la tabla movie. Fila ignorada.
# El movieId 442 no existe en la tabla movie. Fila ignorada.
# El movieId 444 no existe en la tabla movie. Fila ignorada.
# El movieId 445 no existe en la tabla movie. Fila ignorada.
# El movieId 446 no existe en la tabla movie. Fila ignorada.
# El movieId 448 no existe en la tabla movie. Fila ignorada.
# El movieId 449 no existe en la tabla movie. Fila ignorada.
# El movieId 450 no existe en la tabla movie. Fila ignorada.
# El movieId 451 no existe en la tabla movie. Fila ignorada.
# El movieId 452 no existe en la tabla movie. Fila ignorada.
# El movieId 453 no existe en la tabla movie. Fila ignorada.
# El movieId 454 no existe en la tabla movie. Fila ignorada.
# El movieId 455 no existe en la tabla movie. Fila ignorada.
# El movieId 456 no existe en la tabla movie. Fila ignorada.
# El movieId 457 no existe en la tabla movie. Fila ignorada.
# El movieId 458 no existe en la tabla movie. Fila ignorada.
# El movieId 459 no existe en la tabla movie. Fila ignorada.
# El movieId 460 no existe en la tabla movie. Fila ignorada.
# El movieId 461 no existe en la tabla movie. Fila ignorada.
# El movieId 464 no existe en la tabla movie. Fila ignorada.
# El movieId 466 no existe en la tabla movie. Fila ignorada.
# El movieId 467 no existe en la tabla movie. Fila ignorada.
# El movieId 468 no existe en la tabla movie. Fila ignorada.
# El movieId 469 no existe en la tabla movie. Fila ignorada.
# El movieId 470 no existe en la tabla movie. Fila ignorada.
# El movieId 471 no existe en la tabla movie. Fila ignorada.
# El movieId 472 no existe en la tabla movie. Fila ignorada.
# El movieId 473 no existe en la tabla movie. Fila ignorada.
# El movieId 474 no existe en la tabla movie. Fila ignorada.
# El movieId 475 no existe en la tabla movie. Fila ignorada.
# El movieId 476 no existe en la tabla movie. Fila ignorada.
# El movieId 477 no existe en la tabla movie. Fila ignorada.
# El movieId 478 no existe en la tabla movie. Fila ignorada.
# El movieId 479 no existe en la tabla movie. Fila ignorada.
# El movieId 480 no existe en la tabla movie. Fila ignorada.
# El movieId 481 no existe en la tabla movie. Fila ignorada.
# El movieId 482 no existe en la tabla movie. Fila ignorada.
# El movieId 484 no existe en la tabla movie. Fila ignorada.
# El movieId 485 no existe en la tabla movie. Fila ignorada.
# El movieId 486 no existe en la tabla movie. Fila ignorada.
# El movieId 487 no existe en la tabla movie. Fila ignorada.
# El movieId 488 no existe en la tabla movie. Fila ignorada.
# El movieId 489 no existe en la tabla movie. Fila ignorada.
# El movieId 490 no existe en la tabla movie. Fila ignorada.
# El movieId 491 no existe en la tabla movie. Fila ignorada.
# El movieId 492 no existe en la tabla movie. Fila ignorada.
# El movieId 493 no existe en la tabla movie. Fila ignorada.
# El movieId 494 no existe en la tabla movie. Fila ignorada.
# El movieId 495 no existe en la tabla movie. Fila ignorada.
# El movieId 496 no existe en la tabla movie. Fila ignorada.
# El movieId 497 no existe en la tabla movie. Fila ignorada.
# El movieId 499 no existe en la tabla movie. Fila ignorada.
# El movieId 500 no existe en la tabla movie. Fila ignorada.
# El movieId 501 no existe en la tabla movie. Fila ignorada.
# El movieId 502 no existe en la tabla movie. Fila ignorada.
# El movieId 504 no existe en la tabla movie. Fila ignorada.
# El movieId 505 no existe en la tabla movie. Fila ignorada.
# El movieId 506 no existe en la tabla movie. Fila ignorada.
# El movieId 507 no existe en la tabla movie. Fila ignorada.
# El movieId 508 no existe en la tabla movie. Fila ignorada.
# El movieId 509 no existe en la tabla movie. Fila ignorada.
# El movieId 510 no existe en la tabla movie. Fila ignorada.
# El movieId 511 no existe en la tabla movie. Fila ignorada.
# El movieId 512 no existe en la tabla movie. Fila ignorada.
# El movieId 513 no existe en la tabla movie. Fila ignorada.
# El movieId 514 no existe en la tabla movie. Fila ignorada.
# El movieId 515 no existe en la tabla movie. Fila ignorada.
# El movieId 516 no existe en la tabla movie. Fila ignorada.
# El movieId 517 no existe en la tabla movie. Fila ignorada.
# El movieId 518 no existe en la tabla movie. Fila ignorada.
# El movieId 519 no existe en la tabla movie. Fila ignorada.
# El movieId 520 no existe en la tabla movie. Fila ignorada.
# El movieId 521 no existe en la tabla movie. Fila ignorada.
# El movieId 522 no existe en la tabla movie. Fila ignorada.
# El movieId 523 no existe en la tabla movie. Fila ignorada.
# El movieId 524 no existe en la tabla movie. Fila ignorada.
# El movieId 526 no existe en la tabla movie. Fila ignorada.
# El movieId 527 no existe en la tabla movie. Fila ignorada.
# El movieId 528 no existe en la tabla movie. Fila ignorada.
# El movieId 529 no existe en la tabla movie. Fila ignorada.
# El movieId 531 no existe en la tabla movie. Fila ignorada.
# El movieId 532 no existe en la tabla movie. Fila ignorada.
# El movieId 533 no existe en la tabla movie. Fila ignorada.
# El movieId 534 no existe en la tabla movie. Fila ignorada.
# El movieId 535 no existe en la tabla movie. Fila ignorada.
# El movieId 536 no existe en la tabla movie. Fila ignorada.
# El movieId 537 no existe en la tabla movie. Fila ignorada.
# El movieId 538 no existe en la tabla movie. Fila ignorada.
# El movieId 539 no existe en la tabla movie. Fila ignorada.
# El movieId 540 no existe en la tabla movie. Fila ignorada.
# El movieId 541 no existe en la tabla movie. Fila ignorada.
# El movieId 542 no existe en la tabla movie. Fila ignorada.
# El movieId 543 no existe en la tabla movie. Fila ignorada.
# El movieId 544 no existe en la tabla movie. Fila ignorada.
# El movieId 546 no existe en la tabla movie. Fila ignorada.
# El movieId 547 no existe en la tabla movie. Fila ignorada.
# El movieId 548 no existe en la tabla movie. Fila ignorada.
# El movieId 549 no existe en la tabla movie. Fila ignorada.
# El movieId 550 no existe en la tabla movie. Fila ignorada.
# El movieId 551 no existe en la tabla movie. Fila ignorada.
# El movieId 552 no existe en la tabla movie. Fila ignorada.
# El movieId 553 no existe en la tabla movie. Fila ignorada.
# El movieId 555 no existe en la tabla movie. Fila ignorada.
# El movieId 556 no existe en la tabla movie. Fila ignorada.
# El movieId 558 no existe en la tabla movie. Fila ignorada.
# El movieId 562 no existe en la tabla movie. Fila ignorada.
# El movieId 563 no existe en la tabla movie. Fila ignorada.
# El movieId 564 no existe en la tabla movie. Fila ignorada.
# El movieId 567 no existe en la tabla movie. Fila ignorada.
# El movieId 568 no existe en la tabla movie. Fila ignorada.
# El movieId 569 no existe en la tabla movie. Fila ignorada.
# El movieId 573 no existe en la tabla movie. Fila ignorada.
# El movieId 574 no existe en la tabla movie. Fila ignorada.
# El movieId 575 no existe en la tabla movie. Fila ignorada.
# El movieId 577 no existe en la tabla movie. Fila ignorada.
# El movieId 579 no existe en la tabla movie. Fila ignorada.
# El movieId 580 no existe en la tabla movie. Fila ignorada.
# El movieId 581 no existe en la tabla movie. Fila ignorada.
# El movieId 583 no existe en la tabla movie. Fila ignorada.
# El movieId 585 no existe en la tabla movie. Fila ignorada.
# El movieId 586 no existe en la tabla movie. Fila ignorada.
# El movieId 587 no existe en la tabla movie. Fila ignorada.
# El movieId 588 no existe en la tabla movie. Fila ignorada.
# El movieId 589 no existe en la tabla movie. Fila ignorada.
# El movieId 590 no existe en la tabla movie. Fila ignorada.
# El movieId 592 no existe en la tabla movie. Fila ignorada.
# El movieId 593 no existe en la tabla movie. Fila ignorada.
# El movieId 594 no existe en la tabla movie. Fila ignorada.
# El movieId 595 no existe en la tabla movie. Fila ignorada.
# El movieId 596 no existe en la tabla movie. Fila ignorada.
# El movieId 597 no existe en la tabla movie. Fila ignorada.
# El movieId 599 no existe en la tabla movie. Fila ignorada.
# El movieId 600 no existe en la tabla movie. Fila ignorada.
# El movieId 602 no existe en la tabla movie. Fila ignorada.
# El movieId 605 no existe en la tabla movie. Fila ignorada.
# El movieId 606 no existe en la tabla movie. Fila ignorada.
# El movieId 608 no existe en la tabla movie. Fila ignorada.
# El movieId 609 no existe en la tabla movie. Fila ignorada.
# El movieId 610 no existe en la tabla movie. Fila ignorada.
# El movieId 611 no existe en la tabla movie. Fila ignorada.
# El movieId 612 no existe en la tabla movie. Fila ignorada.
# El movieId 613 no existe en la tabla movie. Fila ignorada.
# El movieId 615 no existe en la tabla movie. Fila ignorada.
# El movieId 616 no existe en la tabla movie. Fila ignorada.
# El movieId 617 no existe en la tabla movie. Fila ignorada.
# El movieId 618 no existe en la tabla movie. Fila ignorada.
# El movieId 619 no existe en la tabla movie. Fila ignorada.
# El movieId 626 no existe en la tabla movie. Fila ignorada.
# El movieId 627 no existe en la tabla movie. Fila ignorada.
# El movieId 628 no existe en la tabla movie. Fila ignorada.
# El movieId 631 no existe en la tabla movie. Fila ignorada.
# El movieId 632 no existe en la tabla movie. Fila ignorada.
# El movieId 633 no existe en la tabla movie. Fila ignorada.
# El movieId 634 no existe en la tabla movie. Fila ignorada.
# El movieId 635 no existe en la tabla movie. Fila ignorada.
# El movieId 636 no existe en la tabla movie. Fila ignorada.
# El movieId 637 no existe en la tabla movie. Fila ignorada.
# El movieId 638 no existe en la tabla movie. Fila ignorada.
# El movieId 639 no existe en la tabla movie. Fila ignorada.
# El movieId 640 no existe en la tabla movie. Fila ignorada.
# El movieId 645 no existe en la tabla movie. Fila ignorada.
# El movieId 647 no existe en la tabla movie. Fila ignorada.
# El movieId 648 no existe en la tabla movie. Fila ignorada.
# El movieId 649 no existe en la tabla movie. Fila ignorada.
# El movieId 650 no existe en la tabla movie. Fila ignorada.
# El movieId 653 no existe en la tabla movie. Fila ignorada.
# El movieId 656 no existe en la tabla movie. Fila ignorada.
# El movieId 661 no existe en la tabla movie. Fila ignorada.
# El movieId 662 no existe en la tabla movie. Fila ignorada.
# El movieId 663 no existe en la tabla movie. Fila ignorada.
# El movieId 665 no existe en la tabla movie. Fila ignorada.
# El movieId 667 no existe en la tabla movie. Fila ignorada.
# El movieId 668 no existe en la tabla movie. Fila ignorada.
# El movieId 670 no existe en la tabla movie. Fila ignorada.
# El movieId 671 no existe en la tabla movie. Fila ignorada.
# El movieId 673 no existe en la tabla movie. Fila ignorada.
# El movieId 674 no existe en la tabla movie. Fila ignorada.
# El movieId 678 no existe en la tabla movie. Fila ignorada.
# El movieId 679 no existe en la tabla movie. Fila ignorada.
# El movieId 680 no existe en la tabla movie. Fila ignorada.
# El movieId 685 no existe en la tabla movie. Fila ignorada.
# El movieId 688 no existe en la tabla movie. Fila ignorada.
# El movieId 691 no existe en la tabla movie. Fila ignorada.
# El movieId 692 no existe en la tabla movie. Fila ignorada.
# El movieId 694 no existe en la tabla movie. Fila ignorada.
# El movieId 695 no existe en la tabla movie. Fila ignorada.
# El movieId 697 no existe en la tabla movie. Fila ignorada.
# El movieId 698 no existe en la tabla movie. Fila ignorada.
# El movieId 700 no existe en la tabla movie. Fila ignorada.
# El movieId 703 no existe en la tabla movie. Fila ignorada.
# El movieId 704 no existe en la tabla movie. Fila ignorada.
# El movieId 706 no existe en la tabla movie. Fila ignorada.
# El movieId 707 no existe en la tabla movie. Fila ignorada.
# El movieId 708 no existe en la tabla movie. Fila ignorada.
# El movieId 709 no existe en la tabla movie. Fila ignorada.
# El movieId 710 no existe en la tabla movie. Fila ignorada.
# El movieId 711 no existe en la tabla movie. Fila ignorada.
# El movieId 714 no existe en la tabla movie. Fila ignorada.
# El movieId 715 no existe en la tabla movie. Fila ignorada.
# El movieId 718 no existe en la tabla movie. Fila ignorada.
# El movieId 719 no existe en la tabla movie. Fila ignorada.
# El movieId 720 no existe en la tabla movie. Fila ignorada.
# El movieId 722 no existe en la tabla movie. Fila ignorada.
# El movieId 724 no existe en la tabla movie. Fila ignorada.
# El movieId 725 no existe en la tabla movie. Fila ignorada.
# El movieId 726 no existe en la tabla movie. Fila ignorada.
# El movieId 728 no existe en la tabla movie. Fila ignorada.
# El movieId 731 no existe en la tabla movie. Fila ignorada.
# El movieId 733 no existe en la tabla movie. Fila ignorada.
# El movieId 735 no existe en la tabla movie. Fila ignorada.
# El movieId 736 no existe en la tabla movie. Fila ignorada.
# El movieId 737 no existe en la tabla movie. Fila ignorada.
# El movieId 741 no existe en la tabla movie. Fila ignorada.
# El movieId 742 no existe en la tabla movie. Fila ignorada.
# El movieId 743 no existe en la tabla movie. Fila ignorada.
# El movieId 745 no existe en la tabla movie. Fila ignorada.
# El movieId 747 no existe en la tabla movie. Fila ignorada.
# El movieId 748 no existe en la tabla movie. Fila ignorada.
# El movieId 750 no existe en la tabla movie. Fila ignorada.
# El movieId 757 no existe en la tabla movie. Fila ignorada.
# El movieId 759 no existe en la tabla movie. Fila ignorada.
# El movieId 760 no existe en la tabla movie. Fila ignorada.
# El movieId 761 no existe en la tabla movie. Fila ignorada.
# El movieId 762 no existe en la tabla movie. Fila ignorada.
# El movieId 764 no existe en la tabla movie. Fila ignorada.
# El movieId 765 no existe en la tabla movie. Fila ignorada.
# El movieId 766 no existe en la tabla movie. Fila ignorada.
# El movieId 773 no existe en la tabla movie. Fila ignorada.
# El movieId 775 no existe en la tabla movie. Fila ignorada.
# El movieId 778 no existe en la tabla movie. Fila ignorada.
# El movieId 779 no existe en la tabla movie. Fila ignorada.
# El movieId 780 no existe en la tabla movie. Fila ignorada.
# El movieId 781 no existe en la tabla movie. Fila ignorada.
# El movieId 782 no existe en la tabla movie. Fila ignorada.
# El movieId 783 no existe en la tabla movie. Fila ignorada.
# El movieId 784 no existe en la tabla movie. Fila ignorada.
# El movieId 785 no existe en la tabla movie. Fila ignorada.
# El movieId 786 no existe en la tabla movie. Fila ignorada.
# El movieId 788 no existe en la tabla movie. Fila ignorada.
# El movieId 790 no existe en la tabla movie. Fila ignorada.
# El movieId 791 no existe en la tabla movie. Fila ignorada.
# El movieId 795 no existe en la tabla movie. Fila ignorada.
# El movieId 798 no existe en la tabla movie. Fila ignorada.
# El movieId 799 no existe en la tabla movie. Fila ignorada.
# El movieId 800 no existe en la tabla movie. Fila ignorada.
# El movieId 801 no existe en la tabla movie. Fila ignorada.
# El movieId 802 no existe en la tabla movie. Fila ignorada.
# El movieId 803 no existe en la tabla movie. Fila ignorada.
# El movieId 804 no existe en la tabla movie. Fila ignorada.
# El movieId 805 no existe en la tabla movie. Fila ignorada.
# El movieId 806 no existe en la tabla movie. Fila ignorada.
# El movieId 808 no existe en la tabla movie. Fila ignorada.
# El movieId 809 no existe en la tabla movie. Fila ignorada.
# El movieId 810 no existe en la tabla movie. Fila ignorada.
# El movieId 813 no existe en la tabla movie. Fila ignorada.
# El movieId 818 no existe en la tabla movie. Fila ignorada.
# El movieId 823 no existe en la tabla movie. Fila ignorada.
# El movieId 824 no existe en la tabla movie. Fila ignorada.
# El movieId 828 no existe en la tabla movie. Fila ignorada.
# El movieId 829 no existe en la tabla movie. Fila ignorada.
# El movieId 830 no existe en la tabla movie. Fila ignorada.
# El movieId 832 no existe en la tabla movie. Fila ignorada.
# El movieId 833 no existe en la tabla movie. Fila ignorada.
# El movieId 835 no existe en la tabla movie. Fila ignorada.
# El movieId 836 no existe en la tabla movie. Fila ignorada.
# El movieId 837 no existe en la tabla movie. Fila ignorada.
# El movieId 838 no existe en la tabla movie. Fila ignorada.
# El movieId 839 no existe en la tabla movie. Fila ignorada.
# El movieId 840 no existe en la tabla movie. Fila ignorada.
# El movieId 841 no existe en la tabla movie. Fila ignorada.
# El movieId 842 no existe en la tabla movie. Fila ignorada.
# El movieId 848 no existe en la tabla movie. Fila ignorada.
# El movieId 849 no existe en la tabla movie. Fila ignorada.
# El movieId 851 no existe en la tabla movie. Fila ignorada.
# El movieId 852 no existe en la tabla movie. Fila ignorada.
# El movieId 858 no existe en la tabla movie. Fila ignorada.
# El movieId 861 no existe en la tabla movie. Fila ignorada.
# El movieId 866 no existe en la tabla movie. Fila ignorada.
# El movieId 867 no existe en la tabla movie. Fila ignorada.
# El movieId 869 no existe en la tabla movie. Fila ignorada.
# El movieId 870 no existe en la tabla movie. Fila ignorada.
# El movieId 875 no existe en la tabla movie. Fila ignorada.
# El movieId 876 no existe en la tabla movie. Fila ignorada.
# El movieId 879 no existe en la tabla movie. Fila ignorada.
# El movieId 880 no existe en la tabla movie. Fila ignorada.
# El movieId 881 no existe en la tabla movie. Fila ignorada.
# El movieId 882 no existe en la tabla movie. Fila ignorada.
# El movieId 885 no existe en la tabla movie. Fila ignorada.
# El movieId 886 no existe en la tabla movie. Fila ignorada.
# El movieId 888 no existe en la tabla movie. Fila ignorada.
# El movieId 889 no existe en la tabla movie. Fila ignorada.
# El movieId 891 no existe en la tabla movie. Fila ignorada.
# El movieId 892 no existe en la tabla movie. Fila ignorada.
# El movieId 893 no existe en la tabla movie. Fila ignorada.
# El movieId 896 no existe en la tabla movie. Fila ignorada.
# El movieId 897 no existe en la tabla movie. Fila ignorada.
# El movieId 898 no existe en la tabla movie. Fila ignorada.
# El movieId 899 no existe en la tabla movie. Fila ignorada.
# El movieId 900 no existe en la tabla movie. Fila ignorada.
# El movieId 901 no existe en la tabla movie. Fila ignorada.
# El movieId 902 no existe en la tabla movie. Fila ignorada.
# El movieId 903 no existe en la tabla movie. Fila ignorada.
# El movieId 904 no existe en la tabla movie. Fila ignorada.
# El movieId 905 no existe en la tabla movie. Fila ignorada.
# El movieId 906 no existe en la tabla movie. Fila ignorada.
# El movieId 907 no existe en la tabla movie. Fila ignorada.
# El movieId 908 no existe en la tabla movie. Fila ignorada.
# El movieId 909 no existe en la tabla movie. Fila ignorada.
# El movieId 910 no existe en la tabla movie. Fila ignorada.
# El movieId 911 no existe en la tabla movie. Fila ignorada.
# El movieId 912 no existe en la tabla movie. Fila ignorada.
# El movieId 913 no existe en la tabla movie. Fila ignorada.
# El movieId 914 no existe en la tabla movie. Fila ignorada.
# El movieId 915 no existe en la tabla movie. Fila ignorada.
# El movieId 916 no existe en la tabla movie. Fila ignorada.
# El movieId 917 no existe en la tabla movie. Fila ignorada.
# El movieId 918 no existe en la tabla movie. Fila ignorada.
# El movieId 919 no existe en la tabla movie. Fila ignorada.
# El movieId 920 no existe en la tabla movie. Fila ignorada.
# El movieId 921 no existe en la tabla movie. Fila ignorada.
# El movieId 922 no existe en la tabla movie. Fila ignorada.
# El movieId 923 no existe en la tabla movie. Fila ignorada.
# El movieId 924 no existe en la tabla movie. Fila ignorada.
# El movieId 926 no existe en la tabla movie. Fila ignorada.
# El movieId 927 no existe en la tabla movie. Fila ignorada.
# El movieId 928 no existe en la tabla movie. Fila ignorada.
# El movieId 929 no existe en la tabla movie. Fila ignorada.
# El movieId 930 no existe en la tabla movie. Fila ignorada.
# El movieId 931 no existe en la tabla movie. Fila ignorada.
# El movieId 932 no existe en la tabla movie. Fila ignorada.
# El movieId 933 no existe en la tabla movie. Fila ignorada.
# El movieId 934 no existe en la tabla movie. Fila ignorada.
# El movieId 935 no existe en la tabla movie. Fila ignorada.
# El movieId 936 no existe en la tabla movie. Fila ignorada.
# El movieId 937 no existe en la tabla movie. Fila ignorada.
# El movieId 938 no existe en la tabla movie. Fila ignorada.
# El movieId 940 no existe en la tabla movie. Fila ignorada.
# El movieId 941 no existe en la tabla movie. Fila ignorada.
# El movieId 942 no existe en la tabla movie. Fila ignorada.
# El movieId 943 no existe en la tabla movie. Fila ignorada.
# El movieId 944 no existe en la tabla movie. Fila ignorada.
# El movieId 945 no existe en la tabla movie. Fila ignorada.
# El movieId 946 no existe en la tabla movie. Fila ignorada.
# El movieId 947 no existe en la tabla movie. Fila ignorada.
# El movieId 948 no existe en la tabla movie. Fila ignorada.
# El movieId 949 no existe en la tabla movie. Fila ignorada.
# El movieId 950 no existe en la tabla movie. Fila ignorada.
# El movieId 951 no existe en la tabla movie. Fila ignorada.
# El movieId 952 no existe en la tabla movie. Fila ignorada.
# El movieId 953 no existe en la tabla movie. Fila ignorada.
# El movieId 954 no existe en la tabla movie. Fila ignorada.
# El movieId 955 no existe en la tabla movie. Fila ignorada.
# El movieId 956 no existe en la tabla movie. Fila ignorada.
# El movieId 959 no existe en la tabla movie. Fila ignorada.
# El movieId 961 no existe en la tabla movie. Fila ignorada.
# El movieId 963 no existe en la tabla movie. Fila ignorada.
# El movieId 965 no existe en la tabla movie. Fila ignorada.
# El movieId 968 no existe en la tabla movie. Fila ignorada.
# El movieId 969 no existe en la tabla movie. Fila ignorada.
# El movieId 970 no existe en la tabla movie. Fila ignorada.
# El movieId 971 no existe en la tabla movie. Fila ignorada.
# El movieId 973 no existe en la tabla movie. Fila ignorada.
# El movieId 976 no existe en la tabla movie. Fila ignorada.
# El movieId 979 no existe en la tabla movie. Fila ignorada.
# El movieId 981 no existe en la tabla movie. Fila ignorada.
# El movieId 982 no existe en la tabla movie. Fila ignorada.
# El movieId 984 no existe en la tabla movie. Fila ignorada.
# El movieId 986 no existe en la tabla movie. Fila ignorada.
# El movieId 987 no existe en la tabla movie. Fila ignorada.
# El movieId 988 no existe en la tabla movie. Fila ignorada.
# El movieId 990 no existe en la tabla movie. Fila ignorada.
# El movieId 991 no existe en la tabla movie. Fila ignorada.
# El movieId 993 no existe en la tabla movie. Fila ignorada.
# El movieId 994 no existe en la tabla movie. Fila ignorada.
# El movieId 996 no existe en la tabla movie. Fila ignorada.
# El movieId 998 no existe en la tabla movie. Fila ignorada.
# El movieId 999 no existe en la tabla movie. Fila ignorada.
# El movieId 1003 no existe en la tabla movie. Fila ignorada.
# El movieId 1004 no existe en la tabla movie. Fila ignorada.
# El movieId 1005 no existe en la tabla movie. Fila ignorada.
# El movieId 1006 no existe en la tabla movie. Fila ignorada.
# El movieId 1007 no existe en la tabla movie. Fila ignorada.
# El movieId 1008 no existe en la tabla movie. Fila ignorada.
# El movieId 1009 no existe en la tabla movie. Fila ignorada.
# El movieId 1010 no existe en la tabla movie. Fila ignorada.
# El movieId 1011 no existe en la tabla movie. Fila ignorada.
# El movieId 1012 no existe en la tabla movie. Fila ignorada.
# El movieId 1013 no existe en la tabla movie. Fila ignorada.
# El movieId 1014 no existe en la tabla movie. Fila ignorada.
# El movieId 1015 no existe en la tabla movie. Fila ignorada.
# El movieId 1016 no existe en la tabla movie. Fila ignorada.
# El movieId 1017 no existe en la tabla movie. Fila ignorada.
# El movieId 1018 no existe en la tabla movie. Fila ignorada.
# El movieId 1019 no existe en la tabla movie. Fila ignorada.
# El movieId 1020 no existe en la tabla movie. Fila ignorada.
# El movieId 1021 no existe en la tabla movie. Fila ignorada.
# El movieId 1022 no existe en la tabla movie. Fila ignorada.
# El movieId 1023 no existe en la tabla movie. Fila ignorada.
# El movieId 1024 no existe en la tabla movie. Fila ignorada.
# El movieId 1025 no existe en la tabla movie. Fila ignorada.
# El movieId 1027 no existe en la tabla movie. Fila ignorada.
# El movieId 1028 no existe en la tabla movie. Fila ignorada.
# El movieId 1029 no existe en la tabla movie. Fila ignorada.
# El movieId 1030 no existe en la tabla movie. Fila ignorada.
# El movieId 1031 no existe en la tabla movie. Fila ignorada.
# El movieId 1032 no existe en la tabla movie. Fila ignorada.
# El movieId 1033 no existe en la tabla movie. Fila ignorada.
# El movieId 1034 no existe en la tabla movie. Fila ignorada.
# El movieId 1035 no existe en la tabla movie. Fila ignorada.
# El movieId 1036 no existe en la tabla movie. Fila ignorada.
# El movieId 1037 no existe en la tabla movie. Fila ignorada.
# El movieId 1040 no existe en la tabla movie. Fila ignorada.
# El movieId 1041 no existe en la tabla movie. Fila ignorada.
# El movieId 1042 no existe en la tabla movie. Fila ignorada.
# El movieId 1043 no existe en la tabla movie. Fila ignorada.
# El movieId 1046 no existe en la tabla movie. Fila ignorada.
# El movieId 1047 no existe en la tabla movie. Fila ignorada.
# El movieId 1049 no existe en la tabla movie. Fila ignorada.
# El movieId 1050 no existe en la tabla movie. Fila ignorada.
# El movieId 1051 no existe en la tabla movie. Fila ignorada.
# El movieId 1053 no existe en la tabla movie. Fila ignorada.
# El movieId 1054 no existe en la tabla movie. Fila ignorada.
# El movieId 1055 no existe en la tabla movie. Fila ignorada.
# El movieId 1056 no existe en la tabla movie. Fila ignorada.
# El movieId 1057 no existe en la tabla movie. Fila ignorada.
# El movieId 1059 no existe en la tabla movie. Fila ignorada.
# El movieId 1060 no existe en la tabla movie. Fila ignorada.
# El movieId 1061 no existe en la tabla movie. Fila ignorada.
# El movieId 1064 no existe en la tabla movie. Fila ignorada.
# El movieId 1066 no existe en la tabla movie. Fila ignorada.
# ...
# El movieId 169984 no existe en la tabla movie. Fila ignorada.
# El movieId 169992 no existe en la tabla movie. Fila ignorada.
# El movieId 170289 no existe en la tabla movie. Fila ignorada.
# El movieId 170297 no existe en la tabla movie. Fila ignorada.
# El movieId 170355 no existe en la tabla movie. Fila ignorada.
# El movieId 170357 no existe en la tabla movie. Fila ignorada.
# El movieId 170399 no existe en la tabla movie. Fila ignorada.
# El movieId 170401 no existe en la tabla movie. Fila ignorada.
# El movieId 170411 no existe en la tabla movie. Fila ignorada.
# El movieId 170551 no existe en la tabla movie. Fila ignorada.
# El movieId 170597 no existe en la tabla movie. Fila ignorada.
# El movieId 170697 no existe en la tabla movie. Fila ignorada.
# El movieId 170705 no existe en la tabla movie. Fila ignorada.
# El movieId 170777 no existe en la tabla movie. Fila ignorada.
# El movieId 170813 no existe en la tabla movie. Fila ignorada.
# El movieId 170817 no existe en la tabla movie. Fila ignorada.
# El movieId 170827 no existe en la tabla movie. Fila ignorada.
# El movieId 170837 no existe en la tabla movie. Fila ignorada.
# El movieId 170875 no existe en la tabla movie. Fila ignorada.
# El movieId 170897 no existe en la tabla movie. Fila ignorada.
# El movieId 170907 no existe en la tabla movie. Fila ignorada.
# El movieId 170937 no existe en la tabla movie. Fila ignorada.
# El movieId 170939 no existe en la tabla movie. Fila ignorada.
# El movieId 170945 no existe en la tabla movie. Fila ignorada.
# El movieId 170957 no existe en la tabla movie. Fila ignorada.
# El movieId 170993 no existe en la tabla movie. Fila ignorada.
# El movieId 171011 no existe en la tabla movie. Fila ignorada.
# El movieId 171023 no existe en la tabla movie. Fila ignorada.
# El movieId 171251 no existe en la tabla movie. Fila ignorada.
# El movieId 171495 no existe en la tabla movie. Fila ignorada.
# El movieId 171631 no existe en la tabla movie. Fila ignorada.
# El movieId 171695 no existe en la tabla movie. Fila ignorada.
# El movieId 171701 no existe en la tabla movie. Fila ignorada.
# El movieId 171749 no existe en la tabla movie. Fila ignorada.
# El movieId 171751 no existe en la tabla movie. Fila ignorada.
# El movieId 171759 no existe en la tabla movie. Fila ignorada.
# El movieId 171763 no existe en la tabla movie. Fila ignorada.
# El movieId 171765 no existe en la tabla movie. Fila ignorada.
# El movieId 171811 no existe en la tabla movie. Fila ignorada.
# El movieId 171867 no existe en la tabla movie. Fila ignorada.
# El movieId 171891 no existe en la tabla movie. Fila ignorada.
# El movieId 171917 no existe en la tabla movie. Fila ignorada.
# El movieId 172013 no existe en la tabla movie. Fila ignorada.
# El movieId 172215 no existe en la tabla movie. Fila ignorada.
# El movieId 172229 no existe en la tabla movie. Fila ignorada.
# El movieId 172233 no existe en la tabla movie. Fila ignorada.
# El movieId 172253 no existe en la tabla movie. Fila ignorada.
# El movieId 172321 no existe en la tabla movie. Fila ignorada.
# El movieId 172461 no existe en la tabla movie. Fila ignorada.
# El movieId 172497 no existe en la tabla movie. Fila ignorada.
# El movieId 172547 no existe en la tabla movie. Fila ignorada.
# El movieId 172577 no existe en la tabla movie. Fila ignorada.
# El movieId 172583 no existe en la tabla movie. Fila ignorada.
# El movieId 172585 no existe en la tabla movie. Fila ignorada.
# El movieId 172587 no existe en la tabla movie. Fila ignorada.
# El movieId 172589 no existe en la tabla movie. Fila ignorada.
# El movieId 172591 no existe en la tabla movie. Fila ignorada.
# El movieId 172637 no existe en la tabla movie. Fila ignorada.
# El movieId 172705 no existe en la tabla movie. Fila ignorada.
# El movieId 172793 no existe en la tabla movie. Fila ignorada.
# El movieId 172825 no existe en la tabla movie. Fila ignorada.
# El movieId 172875 no existe en la tabla movie. Fila ignorada.
# El movieId 172881 no existe en la tabla movie. Fila ignorada.
# El movieId 172887 no existe en la tabla movie. Fila ignorada.
# El movieId 172909 no existe en la tabla movie. Fila ignorada.
# El movieId 173145 no existe en la tabla movie. Fila ignorada.
# El movieId 173197 no existe en la tabla movie. Fila ignorada.
# El movieId 173205 no existe en la tabla movie. Fila ignorada.
# El movieId 173209 no existe en la tabla movie. Fila ignorada.
# El movieId 173235 no existe en la tabla movie. Fila ignorada.
# El movieId 173253 no existe en la tabla movie. Fila ignorada.
# El movieId 173255 no existe en la tabla movie. Fila ignorada.
# El movieId 173291 no existe en la tabla movie. Fila ignorada.
# El movieId 173307 no existe en la tabla movie. Fila ignorada.
# El movieId 173317 no existe en la tabla movie. Fila ignorada.
# El movieId 173351 no existe en la tabla movie. Fila ignorada.
# El movieId 173355 no existe en la tabla movie. Fila ignorada.
# El movieId 173535 no existe en la tabla movie. Fila ignorada.
# El movieId 173619 no existe en la tabla movie. Fila ignorada.
# El movieId 173751 no existe en la tabla movie. Fila ignorada.
# El movieId 173873 no existe en la tabla movie. Fila ignorada.
# El movieId 173925 no existe en la tabla movie. Fila ignorada.
# El movieId 173941 no existe en la tabla movie. Fila ignorada.
# El movieId 173963 no existe en la tabla movie. Fila ignorada.
# El movieId 174045 no existe en la tabla movie. Fila ignorada.
# El movieId 174053 no existe en la tabla movie. Fila ignorada.
# El movieId 174055 no existe en la tabla movie. Fila ignorada.
# El movieId 174141 no existe en la tabla movie. Fila ignorada.
# El movieId 174403 no existe en la tabla movie. Fila ignorada.
# El movieId 174479 no existe en la tabla movie. Fila ignorada.
# El movieId 174551 no existe en la tabla movie. Fila ignorada.
# El movieId 174681 no existe en la tabla movie. Fila ignorada.
# El movieId 174727 no existe en la tabla movie. Fila ignorada.
# El movieId 174737 no existe en la tabla movie. Fila ignorada.
# El movieId 174815 no existe en la tabla movie. Fila ignorada.
# El movieId 174909 no existe en la tabla movie. Fila ignorada.
# El movieId 175197 no existe en la tabla movie. Fila ignorada.
# El movieId 175199 no existe en la tabla movie. Fila ignorada.
# El movieId 175293 no existe en la tabla movie. Fila ignorada.
# El movieId 175303 no existe en la tabla movie. Fila ignorada.
# El movieId 175387 no existe en la tabla movie. Fila ignorada.
# El movieId 175397 no existe en la tabla movie. Fila ignorada.
# El movieId 175401 no existe en la tabla movie. Fila ignorada.
# El movieId 175431 no existe en la tabla movie. Fila ignorada.
# El movieId 175435 no existe en la tabla movie. Fila ignorada.
# El movieId 175475 no existe en la tabla movie. Fila ignorada.
# El movieId 175485 no existe en la tabla movie. Fila ignorada.
# El movieId 175569 no existe en la tabla movie. Fila ignorada.
# El movieId 175577 no existe en la tabla movie. Fila ignorada.
# El movieId 175585 no existe en la tabla movie. Fila ignorada.
# El movieId 175661 no existe en la tabla movie. Fila ignorada.
# El movieId 175693 no existe en la tabla movie. Fila ignorada.
# El movieId 175705 no existe en la tabla movie. Fila ignorada.
# El movieId 175707 no existe en la tabla movie. Fila ignorada.
# El movieId 175743 no existe en la tabla movie. Fila ignorada.
# El movieId 175781 no existe en la tabla movie. Fila ignorada.
# El movieId 176051 no existe en la tabla movie. Fila ignorada.
# El movieId 176101 no existe en la tabla movie. Fila ignorada.
# El movieId 176329 no existe en la tabla movie. Fila ignorada.
# El movieId 176371 no existe en la tabla movie. Fila ignorada.
# El movieId 176389 no existe en la tabla movie. Fila ignorada.
# El movieId 176413 no existe en la tabla movie. Fila ignorada.
# El movieId 176415 no existe en la tabla movie. Fila ignorada.
# El movieId 176419 no existe en la tabla movie. Fila ignorada.
# El movieId 176423 no existe en la tabla movie. Fila ignorada.
# El movieId 176579 no existe en la tabla movie. Fila ignorada.
# El movieId 176601 no existe en la tabla movie. Fila ignorada.
# El movieId 176621 no existe en la tabla movie. Fila ignorada.
# El movieId 176751 no existe en la tabla movie. Fila ignorada.
# El movieId 176805 no existe en la tabla movie. Fila ignorada.
# El movieId 176935 no existe en la tabla movie. Fila ignorada.
# El movieId 177185 no existe en la tabla movie. Fila ignorada.
# El movieId 177285 no existe en la tabla movie. Fila ignorada.
# El movieId 177593 no existe en la tabla movie. Fila ignorada.
# El movieId 177615 no existe en la tabla movie. Fila ignorada.
# El movieId 177763 no existe en la tabla movie. Fila ignorada.
# El movieId 177765 no existe en la tabla movie. Fila ignorada.
# El movieId 177939 no existe en la tabla movie. Fila ignorada.
# El movieId 178061 no existe en la tabla movie. Fila ignorada.
# El movieId 178111 no existe en la tabla movie. Fila ignorada.
# El movieId 178129 no existe en la tabla movie. Fila ignorada.
# El movieId 178323 no existe en la tabla movie. Fila ignorada.
# El movieId 178613 no existe en la tabla movie. Fila ignorada.
# El movieId 178615 no existe en la tabla movie. Fila ignorada.
# El movieId 178827 no existe en la tabla movie. Fila ignorada.
# El movieId 179053 no existe en la tabla movie. Fila ignorada.
# El movieId 179073 no existe en la tabla movie. Fila ignorada.
# El movieId 179119 no existe en la tabla movie. Fila ignorada.
# El movieId 179133 no existe en la tabla movie. Fila ignorada.
# El movieId 179135 no existe en la tabla movie. Fila ignorada.
# El movieId 179211 no existe en la tabla movie. Fila ignorada.
# El movieId 179401 no existe en la tabla movie. Fila ignorada.
# El movieId 179427 no existe en la tabla movie. Fila ignorada.
# El movieId 179491 no existe en la tabla movie. Fila ignorada.
# El movieId 179511 no existe en la tabla movie. Fila ignorada.
# El movieId 179709 no existe en la tabla movie. Fila ignorada.
# El movieId 179749 no existe en la tabla movie. Fila ignorada.
# El movieId 179813 no existe en la tabla movie. Fila ignorada.
# El movieId 179815 no existe en la tabla movie. Fila ignorada.
# El movieId 179817 no existe en la tabla movie. Fila ignorada.
# El movieId 179819 no existe en la tabla movie. Fila ignorada.
# El movieId 179953 no existe en la tabla movie. Fila ignorada.
# El movieId 180031 no existe en la tabla movie. Fila ignorada.
# El movieId 180045 no existe en la tabla movie. Fila ignorada.
# El movieId 180095 no existe en la tabla movie. Fila ignorada.
# El movieId 180231 no existe en la tabla movie. Fila ignorada.
# El movieId 180263 no existe en la tabla movie. Fila ignorada.
# El movieId 180265 no existe en la tabla movie. Fila ignorada.
# El movieId 180297 no existe en la tabla movie. Fila ignorada.
# El movieId 180497 no existe en la tabla movie. Fila ignorada.
# El movieId 180777 no existe en la tabla movie. Fila ignorada.
# El movieId 180985 no existe en la tabla movie. Fila ignorada.
# El movieId 180987 no existe en la tabla movie. Fila ignorada.
# El movieId 181065 no existe en la tabla movie. Fila ignorada.
# El movieId 181139 no existe en la tabla movie. Fila ignorada.
# El movieId 181315 no existe en la tabla movie. Fila ignorada.
# El movieId 181413 no existe en la tabla movie. Fila ignorada.
# El movieId 181659 no existe en la tabla movie. Fila ignorada.
# El movieId 181719 no existe en la tabla movie. Fila ignorada.
# El movieId 182293 no existe en la tabla movie. Fila ignorada.
# El movieId 182297 no existe en la tabla movie. Fila ignorada.
# El movieId 182299 no existe en la tabla movie. Fila ignorada.
# El movieId 182639 no existe en la tabla movie. Fila ignorada.
# El movieId 182715 no existe en la tabla movie. Fila ignorada.
# El movieId 182727 no existe en la tabla movie. Fila ignorada.
# El movieId 182731 no existe en la tabla movie. Fila ignorada.
# El movieId 182749 no existe en la tabla movie. Fila ignorada.
# El movieId 182793 no existe en la tabla movie. Fila ignorada.
# El movieId 182823 no existe en la tabla movie. Fila ignorada.
# El movieId 183011 no existe en la tabla movie. Fila ignorada.
# El movieId 183197 no existe en la tabla movie. Fila ignorada.
# El movieId 183199 no existe en la tabla movie. Fila ignorada.
# El movieId 183227 no existe en la tabla movie. Fila ignorada.
# El movieId 183295 no existe en la tabla movie. Fila ignorada.
# El movieId 183301 no existe en la tabla movie. Fila ignorada.
# El movieId 183317 no existe en la tabla movie. Fila ignorada.
# El movieId 183611 no existe en la tabla movie. Fila ignorada.
# El movieId 183635 no existe en la tabla movie. Fila ignorada.
# El movieId 183897 no existe en la tabla movie. Fila ignorada.
# El movieId 183911 no existe en la tabla movie. Fila ignorada.
# El movieId 183959 no existe en la tabla movie. Fila ignorada.
# El movieId 184015 no existe en la tabla movie. Fila ignorada.
# El movieId 184053 no existe en la tabla movie. Fila ignorada.
# El movieId 184245 no existe en la tabla movie. Fila ignorada.
# El movieId 184253 no existe en la tabla movie. Fila ignorada.
# El movieId 184257 no existe en la tabla movie. Fila ignorada.
# El movieId 184349 no existe en la tabla movie. Fila ignorada.
# El movieId 184471 no existe en la tabla movie. Fila ignorada.
# El movieId 184641 no existe en la tabla movie. Fila ignorada.
# El movieId 184721 no existe en la tabla movie. Fila ignorada.
# El movieId 184791 no existe en la tabla movie. Fila ignorada.
# El movieId 184931 no existe en la tabla movie. Fila ignorada.
# El movieId 184987 no existe en la tabla movie. Fila ignorada.
# El movieId 184997 no existe en la tabla movie. Fila ignorada.
# El movieId 185029 no existe en la tabla movie. Fila ignorada.
# El movieId 185031 no existe en la tabla movie. Fila ignorada.
# El movieId 185033 no existe en la tabla movie. Fila ignorada.
# El movieId 185135 no existe en la tabla movie. Fila ignorada.
# El movieId 185435 no existe en la tabla movie. Fila ignorada.
# El movieId 185473 no existe en la tabla movie. Fila ignorada.
# El movieId 185585 no existe en la tabla movie. Fila ignorada.
# El movieId 186587 no existe en la tabla movie. Fila ignorada.
# El movieId 187031 no existe en la tabla movie. Fila ignorada.
# El movieId 187541 no existe en la tabla movie. Fila ignorada.
# El movieId 187593 no existe en la tabla movie. Fila ignorada.
# El movieId 187595 no existe en la tabla movie. Fila ignorada.
# El movieId 187717 no existe en la tabla movie. Fila ignorada.
# El movieId 188189 no existe en la tabla movie. Fila ignorada.
# El movieId 188301 no existe en la tabla movie. Fila ignorada.
# El movieId 188675 no existe en la tabla movie. Fila ignorada.
# El movieId 188751 no existe en la tabla movie. Fila ignorada.
# El movieId 188797 no existe en la tabla movie. Fila ignorada.
# El movieId 188833 no existe en la tabla movie. Fila ignorada.
# El movieId 189043 no existe en la tabla movie. Fila ignorada.
# El movieId 189111 no existe en la tabla movie. Fila ignorada.
# El movieId 189333 no existe en la tabla movie. Fila ignorada.
# El movieId 189381 no existe en la tabla movie. Fila ignorada.
# El movieId 189547 no existe en la tabla movie. Fila ignorada.
# El movieId 189713 no existe en la tabla movie. Fila ignorada.
# El movieId 190183 no existe en la tabla movie. Fila ignorada.
# El movieId 190207 no existe en la tabla movie. Fila ignorada.
# El movieId 190209 no existe en la tabla movie. Fila ignorada.
# El movieId 190213 no existe en la tabla movie. Fila ignorada.
# El movieId 190215 no existe en la tabla movie. Fila ignorada.
# El movieId 190219 no existe en la tabla movie. Fila ignorada.
# El movieId 190221 no existe en la tabla movie. Fila ignorada.
# El movieId 191005 no existe en la tabla movie. Fila ignorada.
# El movieId 193565 no existe en la tabla movie. Fila ignorada.
# El movieId 193567 no existe en la tabla movie. Fila ignorada.
# El movieId 193571 no existe en la tabla movie. Fila ignorada.
# El movieId 193573 no existe en la tabla movie. Fila ignorada.
# El movieId 193579 no existe en la tabla movie. Fila ignorada.
# El movieId 193581 no existe en la tabla movie. Fila ignorada.
# El movieId 193583 no existe en la tabla movie. Fila ignorada.
# El movieId 193585 no existe en la tabla movie. Fila ignorada.
# El movieId 193587 no existe en la tabla movie. Fila ignorada.
# El movieId 193609 no existe en la tabla movie. Fila ignorada.
# Datos cargados exitosamente en la tabla de MySQL.
